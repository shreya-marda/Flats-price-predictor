# %% [markdown]
# ## Real Estate Price Predictor

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
df['LSTAT']
# Out:
# 0      4.98
# 1      9.14
# 2      4.03
# 3      2.94
# 4      5.33
#        ...
# 484    9.67
# 485    9.08
# 486    5.64
# 487    6.48
# 488    7.88
# Name: LSTAT, Length: 489, dtype: float64
# 0      4.98
# 1      9.14
# 2      4.03
# 3      2.94
# 4      5.33
#        ...
# 484    9.67
# 485    9.08
# 486    5.64
# 487    6.48
# 488    7.88
# Name: LSTAT, Length: 489, dtype: float64

# %%
df['LSTAT'].value_counts()
# Out:
# 8.05     3
# 7.79     3
# 6.36     3
# 14.10    3
# 18.13    3
#         ..
# 15.12    1
# 15.79    1
# 12.12    1
# 13.28    1
# 7.88     1
# Name: LSTAT, Length: 442, dtype: int64
# 8.05     3
# 7.79     3
# 6.36     3
# 14.10    3
# 18.13    3
#         ..
# 15.12    1
# 15.79    1
# 12.12    1
# 13.28    1
# 7.88     1
# Name: LSTAT, Length: 442, dtype: int64

# %%
df['RM'].value_counts()
# Out:
# 6.417    3
# 6.167    3
# 6.127    3
# 6.229    3
# 6.405    3
#         ..
# 5.572    1
# 5.880    1
# 5.875    1
# 6.402    1
# 6.976    1
# Name: RM, Length: 430, dtype: int64
# 6.417    3
# 6.167    3
# 6.127    3
# 6.229    3
# 6.405    3
#         ..
# 5.572    1
# 5.880    1
# 5.875    1
# 6.402    1
# 6.976    1
# Name: RM, Length: 430, dtype: int64

# %%
df['PTRATIO'].value_counts()
# Out:
# 20.2    134
# 14.7     29
# 21.0     27
# 17.8     22
# 19.2     19
# 19.1     17
# 17.4     17
# 18.6     17
# 18.4     16
# 16.6     16
# 21.2     15
# 15.2     13
# 17.9     11
# 20.9     11
# 13.0     10
# 18.7      9
# 19.6      8
# 19.7      8
# 17.6      7
# 16.4      6
# 16.9      5
# 16.0      5
# 20.1      5
# 18.0      5
# 16.1      5
# 19.0      4
# 18.3      4
# 16.8      4
# 18.2      4
# 14.9      4
# 18.5      4
# 17.0      4
# 18.9      3
# 14.8      3
# 12.6      3
# 15.3      3
# 15.9      2
# 15.6      2
# 18.8      2
# 22.0      2
# 15.1      1
# 17.3      1
# 21.1      1
# 15.5      1
# Name: PTRATIO, dtype: int64
# 20.2    134
# 14.7     29
# 21.0     27
# 17.8     22
# 19.2     19
# 19.1     17
# 17.4     17
# 18.6     17
# 18.4     16
# 16.6     16
# 21.2     15
# 15.2     13
# 17.9     11
# 20.9     11
# 13.0     10
# 18.7      9
# 19.6      8
# 19.7      8
# 17.6      7
# 16.4      6
# 16.9      5
# 16.0      5
# 20.1      5
# 18.0      5
# 16.1      5
# ...

# %%
df['MEDV'].value_counts()
# Out:
# 525000.0    8
# 485100.0    7
# 462000.0    7
# 455700.0    7
# 407400.0    6
#            ..
# 690900.0    1
# 726600.0    1
# 636300.0    1
# 699300.0    1
# 170100.0    1
# Name: MEDV, Length: 228, dtype: int64
# 525000.0    8
# 485100.0    7
# 462000.0    7
# 455700.0    7
# 407400.0    6
#            ..
# 690900.0    1
# 726600.0    1
# 636300.0    1
# 699300.0    1
# 170100.0    1
# Name: MEDV, Length: 228, dtype: int64

# %%
df.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# ...

# %%
# %matplotlib inline 
#this will tell the system that we want to see our graphs here itself

# %%
#for plotting histogram

import matplotlib.pyplot as plt
df.hist(bins=50, figsize = (20,15))
# Out:
# array([[<Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'LSTAT'}>],
#        [<Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'MEDV'}>]], dtype=object)
# array([[<Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'LSTAT'}>],
#        [<Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'MEDV'}>]], dtype=object)

# %% [markdown]
# ## Splitting the training and testing data

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
#we defined thus function for learning

import numpy as np
def split_train_test(data, test_ratio):
    np.random.seed(42)  #if we dont seed the random value generator for shuffled, in long run the machine will see the whole data and may overfit it which we dont want
    #now we will get the same set of values every time we try printing the train_test_split
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
#train_set, test_set = split_train_test(df, 0.2)

# %%
#print(f"Rows in training set: {len(train_set)}")   #the f"" helps use place variable in the print statement in {}

# %%
#print(f"Rows in testing set: {len(test_set)}")

# %%
#train_set

# %%
#test_set

# %%
#We can also split the training and testing data like this without creating any function
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# %%
print(f"Rows in training set: {len(train_set)}")
print(f"Rows in testing set: {len(test_set)}")
# Out:
# Rows in training set: 391
# Rows in testing set: 98
# Rows in training set: 391
# Rows in testing set: 98

# %%
#We do the stratified shuffle split for mostly the most important feature
#It helps us distribute the data in the training set properly so that there isnt same kind of data in the whole training set
#Else it can give wrong predictions as it may overfit the data
#Specifically when we have 0s and 1s in set
"""
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2,
                               train_size = 0.8, random_state = 42)
for train_index, test_index in split.split(df,df['LSTAT']):
    strat_train_set = df.iloc[train_index]
    strat_test_set = df.iloc[test_index]
"""
# Out:
# "\nfrom sklearn.model_selection import StratifiedShuffleSplit\nsplit = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2,\n                               train_size = 0.8, random_state = 42)\nfor train_index, test_index in split.split(df,df['LSTAT']):\n    strat_train_set = df.iloc[train_index]\n    strat_test_set = df.iloc[test_index]\n"
# "\nfrom sklearn.model_selection import StratifiedShuffleSplit\nsplit = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2,\n                               train_size = 0.8, random_state = 42)\nfor train_index, test_index in split.split(df,df['LSTAT']):\n    strat_train_set = df.iloc[train_index]\n    strat_test_set = df.iloc[test_index]\n"

# %% [markdown]
# ## Looking for Correlations

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                RM     LSTAT   PTRATIO      MEDV
# RM       1.000000 -0.612033 -0.304559  0.697209
# LSTAT   -0.612033  1.000000  0.360445 -0.760670
# PTRATIO -0.304559  0.360445  1.000000 -0.519034
# MEDV     0.697209 -0.760670 -0.519034  1.000000
#                RM     LSTAT   PTRATIO      MEDV
# RM       1.000000 -0.612033 -0.304559  0.697209
# LSTAT   -0.612033  1.000000  0.360445 -0.760670
# PTRATIO -0.304559  0.360445  1.000000 -0.519034
# MEDV     0.697209 -0.760670 -0.519034  1.000000

# %%
#we find the correlation wrt to MEDV(price) to check if it is directly or inversely proportional to the features
corr_matrix['MEDV'].sort_values(ascending=False)
#1: strong positive correlation
#0.69..: directly proportional and increases with RM increasing
#0.34..: not that strong direct proportionality
#-0.519..: negative correlation or inversely proportional
#-0.760..: negtaive correlation and inversly proportional
#-1: strong negative correlation
# Out:
# MEDV       1.000000
# RM         0.697209
# PTRATIO   -0.519034
# LSTAT     -0.760670
# Name: MEDV, dtype: float64
# MEDV       1.000000
# RM         0.697209
# PTRATIO   -0.519034
# LSTAT     -0.760670
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
#in bigger dataframes, we only plot those graphs where the correlation is either strongly positive or strongly negative
#Write this way when you have many features and you are plotting for selected ones
"""
attributes = ['MEDV','RM','PTRATIO','LSTAT']
scatter_matrix(df[attributes], figsize = (12,8))
"""
scatter_matrix(df, figsize = (12,8))
# Out:
# array([[<Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>,
#         <Axes: xlabel='PTRATIO', ylabel='RM'>,
#         <Axes: xlabel='MEDV', ylabel='RM'>],
#        [<Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>,
#         <Axes: xlabel='PTRATIO', ylabel='LSTAT'>,
#         <Axes: xlabel='MEDV', ylabel='LSTAT'>],
#        [<Axes: xlabel='RM', ylabel='PTRATIO'>,
#         <Axes: xlabel='LSTAT', ylabel='PTRATIO'>,
#         <Axes: xlabel='PTRATIO', ylabel='PTRATIO'>,
#         <Axes: xlabel='MEDV', ylabel='PTRATIO'>],
#        [<Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>,
#         <Axes: xlabel='PTRATIO', ylabel='MEDV'>,
#         <Axes: xlabel='MEDV', ylabel='MEDV'>]], dtype=object)
# array([[<Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>,
#         <Axes: xlabel='PTRATIO', ylabel='RM'>,
#         <Axes: xlabel='MEDV', ylabel='RM'>],
# ...

# %%
#for MEDV vs MEDV it plots a histogram instead of straight lines
#for RM vs MEDV you can see the strong positive correlation with a straight line with a positive slope
#for LSAT vs MEDV you can the strong negative correlation with straight line with a negative slope

# %%
df.plot(kind = "scatter", x="RM", y="MEDV", alpha=0.8)
#alpha refers to the darkness of the colours on the plot
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
#You can also try different attribute combinations to get better positive or negative correlations

# %%
df = train_set.drop("MEDV",axis=1)
df_label = train_set["MEDV"].copy()

# %% [markdown]
# ## Missing attributes
# #### Taking care of missing attributes
# 1. Get rid of the missing attributes
# 2. Get rid of the whole attribute
# 3. Set the value of the missing attributes to 0, mean or median

# %%
#1. df.dropna(subset = ["<<column name>>"],inplace=True) (inplace=True - will chage the origibal df)
#2. df.drop("<<columnname>>",axis=1)
#3. median = df["<<Columnname"].median()
#   df["<<columnname"].fillna(median)
#split the data into traing and testing set mostly after this

# %%
df.describe()  #BEFORE IMPUTING
# Out:
#                RM       LSTAT     PTRATIO
# count  391.000000  391.000000  391.000000
# mean     6.257668   12.836598   18.441432
# std      0.674118    7.127752    2.181947
# min      3.561000    1.980000   12.600000
# 25%      5.886000    7.195000   17.000000
# 50%      6.195000   11.410000   18.900000
# 75%      6.630000   16.920000   20.200000
# max      8.398000   37.970000   22.000000
#                RM       LSTAT     PTRATIO
# count  391.000000  391.000000  391.000000
# mean     6.257668   12.836598   18.441432
# std      0.674118    7.127752    2.181947
# min      3.561000    1.980000   12.600000
# 25%      5.886000    7.195000   17.000000
# 50%      6.195000   11.410000   18.900000
# 75%      6.630000   16.920000   20.200000
# max      8.398000   37.970000   22.000000

# %% [markdown]
# ## Imputing

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
imputer.fit(df)
# Out:
# SimpleImputer(strategy='median')
# SimpleImputer(strategy='median')

# %%
imputer.statistics_.shape
#calculates the statistics for all the 4 columns
# Out:
# (3,)
# (3,)

# %%
imputer.statistics_
# Out:
# array([ 6.195, 11.41 , 18.9  ])
# array([ 6.195, 11.41 , 18.9  ])

# %%
X = imputer.transform(df)

# %%
X
# Out:
# array([[ 5.869,  9.8  , 20.2  ],
#        [ 6.174, 24.16 , 21.2  ],
#        [ 6.749, 17.44 , 20.2  ],
#        ...,
#        [ 6.112, 12.67 , 20.2  ],
#        [ 6.297, 17.27 , 20.2  ],
#        [ 6.405, 10.63 , 20.9  ]])
# array([[ 5.869,  9.8  , 20.2  ],
#        [ 6.174, 24.16 , 21.2  ],
#        [ 6.749, 17.44 , 20.2  ],
#        ...,
#        [ 6.112, 12.67 , 20.2  ],
#        [ 6.297, 17.27 , 20.2  ],
#        [ 6.405, 10.63 , 20.9  ]])

# %%
df_ = pd.DataFrame(X, columns=df.columns)

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       391 non-null    float64
#  1   LSTAT    391 non-null    float64
#  2   PTRATIO  391 non-null    float64
# dtypes: float64(3)
# memory usage: 9.3 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       391 non-null    float64
#  1   LSTAT    391 non-null    float64
#  2   PTRATIO  391 non-null    float64
# dtypes: float64(3)
# memory usage: 9.3 KB

# %%
df_.describe()
# Out:
#                RM       LSTAT     PTRATIO
# count  391.000000  391.000000  391.000000
# mean     6.257668   12.836598   18.441432
# std      0.674118    7.127752    2.181947
# min      3.561000    1.980000   12.600000
# 25%      5.886000    7.195000   17.000000
# 50%      6.195000   11.410000   18.900000
# 75%      6.630000   16.920000   20.200000
# max      8.398000   37.970000   22.000000
#                RM       LSTAT     PTRATIO
# count  391.000000  391.000000  391.000000
# mean     6.257668   12.836598   18.441432
# std      0.674118    7.127752    2.181947
# min      3.561000    1.980000   12.600000
# 25%      5.886000    7.195000   17.000000
# 50%      6.195000   11.410000   18.900000
# 75%      6.630000   16.920000   20.200000
# max      8.398000   37.970000   22.000000

# %% [markdown]
# ## Scikit Learn design

# %% [markdown]
# There are primariliy three types of objects
# 1. Estimators - It estimates some parameters Eg. Imputer. It has a fit method and transform method. Fit method: fits the dataset and calculates internal parameters.
#
# 2. Transformers - Transform method takes input and returns output based on the learnings from fit(). It alsa has convenience function called fit_transform() which fits and then transforms.
#
# 3. Predictors - LinearRegression model is an example of predictor, fit() and predict() are two common functions. It also gives score function whic will evaluate the predictions.

# %% [markdown]
# ## Feature scaling

# %% [markdown]
# Primarily two types of feature scaling methods:
# 1. Min-max scaling (Normalisation)
#
#     (value-min)/(max-min)
#
#     sklearn provides a class called MinMaxScaler for this
# 2. Standardisation
#
#     (value-min)/std
#
#     sklearn provides a class called Standard Scaker for this

# %% [markdown]
# ## Creating a Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
#   ... add as many as you want in your pipeline
    ('std_scaler',StandardScaler()),
])

# %%
df_num_tr = my_pipeline.fit_transform(df_)

# %%
df_num_tr
# Out:
# array([[-0.57729555, -0.42657057,  0.80699513],
#        [-0.12427302,  1.59067125,  1.26588852],
#        [ 0.72978585,  0.64666951,  0.80699513],
#        ...,
#        [-0.21636285, -0.02340316,  0.80699513],
#        [ 0.05842131,  0.62278851,  0.80699513],
#        [ 0.21883585, -0.30997512,  1.1282205 ]])
# array([[-0.57729555, -0.42657057,  0.80699513],
#        [-0.12427302,  1.59067125,  1.26588852],
#        [ 0.72978585,  0.64666951,  0.80699513],
#        ...,
#        [-0.21636285, -0.02340316,  0.80699513],
#        [ 0.05842131,  0.62278851,  0.80699513],
#        [ 0.21883585, -0.30997512,  1.1282205 ]])

# %% [markdown]
# ## Selecting a desired model for the problem

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model = LinearRegression()
#model = DecisionTreeRegressor()
model = RandomForestRegressor()
model.fit(df,df_label)
# Out:
# RandomForestRegressor()
# RandomForestRegressor()

# %%
some_labels = df_label.iloc[:5]

# %%
some_data = df.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([514521., 514521., 514521., 514521., 514521.])
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([514521., 514521., 514521., 514521., 514521.])

# %%
some_labels
# Out:
# 325    409500.0
# 140    294000.0
# 433    281400.0
# 416    300300.0
# 487    462000.0
# Name: MEDV, dtype: float64
# 325    409500.0
# 140    294000.0
# 433    281400.0
# 416    300300.0
# 487    462000.0
# Name: MEDV, dtype: float64

# %%
list(some_labels)
# Out:
# [409500.0, 294000.0, 281400.0, 300300.0, 462000.0]
# [409500.0, 294000.0, 281400.0, 300300.0, 462000.0]

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
df_predictions = model.predict(df_num_tr)
mse = mean_squared_error(df_label, df_predictions)
rmse = np.sqrt(mse)
# Out:
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
rmse
# Out:
# 176409.73243931873
# 176409.73243931873

# %% [markdown]
# ## Using better evaluation technique - cross validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, df_num_tr, df_label, scoring="neg_mean_squared_error", cv =10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([60236.79182692, 77704.14487905, 83366.69266836, 88645.15228188,
#        73806.72775619, 75254.15928756, 70323.02562078, 66970.94942528,
#        64317.97240454, 58624.20094978])
# array([60236.79182692, 77704.14487905, 83366.69266836, 88645.15228188,
#        73806.72775619, 75254.15928756, 70323.02562078, 66970.94942528,
#        64317.97240454, 58624.20094978])

# %%
def print_scores(scores):
    print("Scores: ",scores)
    print("Mean: ",scores.mean())
    print("Standard deviation: ",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores:  [60236.79182692 77704.14487905 83366.69266836 88645.15228188
#  73806.72775619 75254.15928756 70323.02562078 66970.94942528
#  64317.97240454 58624.20094978]
# Mean:  71924.9817100342
# Standard deviation:  9257.428441013039
# Scores:  [60236.79182692 77704.14487905 83366.69266836 88645.15228188
#  73806.72775619 75254.15928756 70323.02562078 66970.94942528
#  64317.97240454 58624.20094978]
# Mean:  71924.9817100342
# Standard deviation:  9257.428441013039

# %% [markdown]
# ## saving the model

# %%
from joblib import dump, load
dump(model, 'real_estate.joblib')
# Out:
# ['real_estate.joblib']
# ['real_estate.joblib']

# %% [markdown]
# ## Testing the model on test data

# %%
X_test = test_set.drop("MEDV",axis=1)
y_test = test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
# Out:
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
final_rmse
# Out:
# 173306.5193263081
# 173306.5193263081

# %%
print(final_predictions, list(y_test))
# Out:
# [514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
#  514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521. 514521.
# ...

# %%
prepared_data[0]
# Out:
# array([-0.57729555, -0.42657057,  0.80699513])
# array([-0.57729555, -0.42657057,  0.80699513])

# %% [markdown]
# ## Using the model

# %%
from joblib import load,dump
import numpy as np
model = load("real_estate.joblib")
features = np.array([[-0.57729555, -0.42657057,  0.80699513]])
model.predict(features)
# Out:
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([514521.])
# C:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([514521.])
